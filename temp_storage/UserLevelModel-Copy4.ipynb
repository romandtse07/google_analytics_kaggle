# %% [markdown]
# # Transaction Level Models
#
# While it was expected that aggregation of features in a somewhat arbitrary manner would result in the loss of information, it was not expected that such an approach would not be able to beat the baseline score of guessing only zeros.

# %%
import pandas as pd
import sqlalchemy
import numpy as np
import pickle

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

from lightgbm import LGBMRegressor
import catboost as cb

from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
from keras.callbacks import EarlyStopping

# %matplotlib inline
# Out:
# /anaconda3/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_9.4.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
engine = sqlalchemy.create_engine('postgresql://romandtse:duckthewut@localhost:5432/training')

# %%
with open('../pickles/field_dict.pkl', 'rb') as f:
    field_dict = pickle.load(f)
    
with open('../pickles/useless_fields.pkl', 'rb') as f:
    useless_fields = pickle.load(f)

with open('../pickles/adwordsClickInfo_keys.pkl', 'rb') as f:
    adwordsClickInfo_keys = pickle.load(f)
    
with open('../pickles/channel_groups.pkl', 'rb') as f:
    channel_groups = pickle.load(f)
    
with open('../pickles/field_vals.pkl', 'rb') as f:
    field_vals = pickle.load(f)

# %% [raw]
# query = """
# SELECT fullVisitorId
# FROM train_data
# GROUP BY fullVisitorId
# HAVING SUM(CAST(totals ->> 'transactionRevenue' AS numeric)) > 0
# """
#
# customers = pd.read_sql_query(query, engine)

# %% [raw]
# with open('../pickles/train_customer_ids.pkl', 'wb') as f:
#     pickle.dump(customers, f)

# %% [raw]
# query = """
# SELECT fullVisitorId
# FROM train_data
# GROUP BY fullVisitorId
# HAVING SUM(CAST(totals ->> 'transactionRevenue' AS numeric)) IS NULL
# """
#
# lookers = pd.read_sql_query(query, engine)

# %% [raw]
# with open('./pickles/train_looker_ids.pkl', 'wb') as f:
#     pickle.dump(lookers, f)

# %%
with open('../pickles/train_customer_ids.pkl', 'rb') as f:
    train_customer_ids = pickle.load(f)

# %% [markdown]
# There is the question of scaling the revenue.  By coincidence, or maybe by design, the target is actually scaled by the natural log.  When we fit a regressor, there will necessarily be negative values.  Since we will send these values through another model, we should consider scaling everything by the natural log here; the argument is not that we pretend a single session should imitate a

# %%
def revTemplate(key, name, num_type = 'FLOAT'):
    return f"""COALESCE(CAST({key} ->> '{name}' AS {num_type}), 0)/10^6 AS {name}"""

def jnumTemplate(key, name, num_type = 'INT'):
    return f"""COALESCE(CAST({key} ->> '{name}' AS {num_type}), 0) AS {name}"""

def numTemplate(name):
    return f"""COALESCE({name}, 0) AS {name}"""

def jstrTemplate(key, name):
    return f"{key} ->> '{name}' AS {name}"

def strTemplate(name):
    return f"{name}"

def adwordsTemplate(name):
    return f"CAST(trafficSource ->> 'adwordsClickInfo' AS JSONB) ->> '{name}' AS {name}"

# %%
def getQuery(dataset = 'train'):
    numeric_cols = ['visitNumber', 'newVisits', 'bounces', 'pageviews', 'visits', 'hits', 'transactionRevenue']
    if dataset != 'train':
        numeric_cols.pop()
    selects = []
    for cat, subcats in field_dict.items():
        for subcat in subcats:
            if subcat not in useless_fields[dataset]:
                if subcat == 'transactionRevenue':
                    selects.append(revTemplate(cat, subcat, 'NUMERIC'))
                elif subcat in numeric_cols:
                    selects.append(jnumTemplate(cat, subcat))
                elif subcat == 'adwordsClickInfo':
                    for key in adwordsClickInfo_keys:
                        selects.append(adwordsTemplate(key))
                else:
                    selects.append(jstrTemplate(cat, subcat))
    selects.extend([numTemplate('visitNumber'), 
                    strTemplate('channelGrouping'),
                    strTemplate('fullVisitorId'),
                    numTemplate('visitStartTime'),
                   ])
    return ', '.join(selects)

# %%
qstring = getQuery()

# %%
with open('../pickles/top_order.pkl', 'rb') as f:
    top_order = pickle.load(f)

# %%
#create user_list by
def getUserData(user_list):
    users = "\', \'".join(user_list)
    query = f"""
    SELECT {qstring}
    FROM train_data
    WHERE fullVisitorId IN (\'{users}\')
    """

    return pd.read_sql_query(query, engine, parse_dates=['visitstarttime'])

# %%
with open('../pickles/objects.pkl', 'rb') as f:
    objects = pickle.load(f)

# %% [markdown]
# By introducing all possible values of fields ahead of time for dummying, independent of whether they show up in the training set or not, we fail to simulate the fact that we have no idea whether we have captured all the features.  The categories included here, though are fairly set in stone; there probably are not many sub continents that have yet to appear in the store's history.

# %%
def adjustCols(df, drop_ids = True):
    back_looking = ['bounces', 'hits', 'newvisits', 'pageviews']
    
    df = df.sort_values(['fullvisitorid','visitstarttime'])
    #turns out the for loop checks col_order dynamically, temporary list needed to avoid infinite loop
    for col in back_looking:
        df[f'{col}last'] = df.groupby('fullvisitorid')[col].shift(1)
        df[f'{col}two'] = df.groupby('fullvisitorid')[col].shift(2)
    df['sincelast'] = df.groupby('fullvisitorid').visitstarttime.diff().map(lambda x: x.days + x.seconds/86400)
    df['sincetwo'] = df.groupby('fullvisitorid').visitstarttime.diff(2).map(lambda x: x.days + x.seconds/86400)
    df['hour'] = df.visitstarttime.map(lambda x: x.hour)
    df['weekday'] = df.visitstarttime.map(lambda x: x.dayofweek)
    
    if drop_ids:
        return df.drop(['fullvisitorid', 'visitstarttime'], axis=1)
    else:
        return df.drop('visitstarttime', axis=1)

# %%
with open('../pickles/train_customer_ids.pkl', 'rb') as f:
    train_customer_ids = pickle.load(f)

# %%
with open('../pickles/train_looker_ids.pkl', 'rb') as f:
    train_looker_ids = pickle.load(f)

# %%
#shuffle now so we can just iterate through lists
from random import shuffle

def stratifiedIdSplit(test_size=0.5):
    customer_size = int(len(train_customer_ids)*test_size)
    looker_size = int(len(train_looker_ids)*test_size)
    
    test_customers = list(np.random.choice(train_customer_ids.T.values[0], replace=False, size=customer_size))
    test_lookers = list(np.random.choice(train_looker_ids.T.values[0], replace=False, size=looker_size))
    
    train_customers = list(set(train_customer_ids.T.values[0]).difference(set(test_customers)))
    train_lookers = list(set(train_looker_ids.T.values[0]).difference(set(test_lookers)))
    
    test_customers.extend(test_lookers)
    train_customers.extend(train_lookers)
    
    shuffle(test_customers)
    shuffle(train_customers)
    
    return train_customers, test_customers

# %%
train_ids, test_ids = stratifiedIdSplit(0.3)

# %% [markdown]
# While we can hope a machine can learn what is unique about this outlier, the fact is that there is no one else like this user.  In our ensemble later, considering it is a system of gradient boosted trees, there is a very good chance that one of the forests will be awful at guessing because it was fit to minimize the error it would get from this outlier point.  With all its activity, though, perhaps the behavior could still fall in line with the other points of data.  For the fear of overfitting to this point, and because our validation can tell us nothing about how well it does on similar outliers (because there are none like it), we remove it from our model for now.

# %%
try:
    train_ids.remove(top_order.iloc[0,0])
except:
    test_ids.remove(top_order.iloc[0,0])

# %%
getUserData([test_ids[0]]).columns
# Out:
# Index(['devicecategory', 'ismobile', 'browser', 'operatingsystem', 'city',
#        'continent', 'country', 'metro', 'networkdomain', 'region',
#        'subcontinent', 'bounces', 'hits', 'newvisits', 'pageviews',
#        'transactionrevenue', 'adcontent', 'adnetworktype',
#        'criteriaparameters', 'gclid', 'isvideoad', 'page', 'slot',
#        'targetingcriteria', 'campaign', 'campaigncode', 'istruedirect',
#        'keyword', 'medium', 'referralpath', 'source', 'visitnumber',
#        'channelgrouping', 'fullvisitorid', 'visitstarttime'],
#       dtype='object')

# %%
def createChunk(ids_list, size, drop_ids = True):
    new_size = len(ids_list)
    if  new_size > size:
        new_size = size
    someppl = ids_list
    shuffle(someppl)
    someppl = someppl[:new_size]
    chunk = getUserData(someppl)
    chunk = adjustCols(chunk, drop_ids)
    
    return chunk.fillna(0), ids_list[new_size:]

# %%
trial_df = adjustCols(getUserData([top_order.iloc[0][0]])).drop('transactionrevenue', axis=1)

# %%
trial_vals = adjustCols(getUserData([top_order.iloc[0][0]])).transactionrevenue

# %%
cat_feets = np.where(trial_df.dtypes == object)[0]

# %%
trial_df.columns[cat_feets]
# Out:
# Index(['devicecategory', 'ismobile', 'browser', 'operatingsystem', 'city',
#        'continent', 'country', 'metro', 'networkdomain', 'region',
#        'subcontinent', 'adcontent', 'adnetworktype', 'criteriaparameters',
#        'gclid', 'isvideoad', 'page', 'slot', 'targetingcriteria', 'campaign',
#        'campaigncode', 'istruedirect', 'keyword', 'medium', 'referralpath',
#        'source', 'channelgrouping'],
#       dtype='object')

# %% [markdown]
# Instead of training a set of trees and losing most of the trees, let's make an ensemble.  We can blend it and fit to the actual target with a single ensemble in two stages; we fit by session while still preventing user leakage before using these to predict the sum of all sessions and fitting on a separate validation set.

# %%
id_holder = train_ids
fold = 8
holdouts = 2
fold_size = len(id_holder)//fold

models = []
first_ids = id_holder[:fold_size].copy()


def trainCB(train_set, eval_pool, model_list):
    model_list.append(cb.CatBoostRegressor(iterations = 500,
                                           learning_rate  = .1,
                                           l2_leaf_reg = 100,
                                           cat_features = cat_feets,
                                           verbose = True))
    model_list[-1].fit(X = train_set.drop('transactionrevenue', axis=1),
                       y = train_set.transactionrevenue,
                       use_best_model = True, 
                       eval_set = eval_pool, 
                       early_stopping_rounds = 10, 
                       metric_period = 50)

eval_chunk, id_holder = createChunk(id_holder, fold_size)
eval_chunk = cb.Pool(eval_chunk.drop('transactionrevenue', axis=1), 
                 eval_chunk.transactionrevenue, 
                 cat_features=cat_feets)
chunk, id_holder = createChunk(id_holder, fold_size)
trainCB(chunk, eval_chunk, models)


for n in range(fold - holdouts - 2):
    eval_chunk = chunk
    eval_chunk = cb.Pool(eval_chunk.drop('transactionrevenue', axis=1), 
                     eval_chunk.transactionrevenue, 
                     cat_features=cat_feets)
    if n < 3:
        chunk, id_holder = createChunk(id_holder, fold_size)
    else:
        chunk = createChunk(first_ids, fold_size)[0]
    trainCB(chunk, eval_chunk, models)
# Out:
# Warning: Overfitting detector is active, thus evaluation metric iscalculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	learn: 35.6141297	test: 67.0926702	best: 67.0926702 (0)	total: 459ms	remaining: 3m 48s
# 50:	learn: 34.0242495	test: 66.6397450	best: 66.6397450 (50)	total: 17.6s	remaining: 2m 34s
# 100:	learn: 33.5665814	test: 66.5808375	best: 66.5808375 (100)	total: 34.6s	remaining: 2m 16s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 66.57089931
# bestIteration = 107
#
# Shrink model to first 108 iterations.
# Warning: Overfitting detector is active, thus evaluation metric iscalculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	learn: 29.4909781	test: 35.6619093	best: 35.6619093 (0)	total: 457ms	remaining: 3m 48s
# 50:	learn: 27.8292836	test: 34.6339357	best: 34.6339357 (50)	total: 19.2s	remaining: 2m 48s
# 100:	learn: 27.2804282	test: 34.4388677	best: 34.4388677 (100)	total: 36.7s	remaining: 2m 24s
# 150:	learn: 26.9199866	test: 34.3520542	best: 34.3520418 (149)	total: 54.6s	remaining: 2m 6s
# 200:	learn: 26.6876952	test: 34.2950701	best: 34.2950701 (200)	total: 1m 11s	remaining: 1m 46s
# 250:	learn: 26.4680033	test: 34.2521019	best: 34.2506934 (246)	total: 1m 29s	remaining: 1m 28s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 34.23564526
# bestIteration = 270
#
# Shrink model to first 271 iterations.
# Warning: Overfitting detector is active, thus evaluation metric iscalculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	learn: 46.7135529	test: 29.4882553	best: 29.4882553 (0)	total: 458ms	remaining: 3m 48s
# 50:	learn: 45.1500831	test: 28.5862330	best: 28.5862330 (50)	total: 17.9s	remaining: 2m 37s
# 100:	learn: 44.5401197	test: 28.4358089	best: 28.4346498 (96)	total: 34.5s	remaining: 2m 16s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 28.42968001
# bestIteration = 106
#
# Shrink model to first 107 iterations.
# Warning: Overfitting detector is active, thus evaluation metric iscalculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	learn: 33.7786868	test: 46.7572169	best: 46.7572169 (0)	total: 385ms	remaining: 3m 11s
# 50:	learn: 31.6877456	test: 45.7699874	best: 45.7699874 (50)	total: 17.5s	remaining: 2m 34s
# 100:	learn: 31.1521536	test: 45.6285858	best: 45.6285858 (100)	total: 34.6s	remaining: 2m 16s
# 150:	learn: 30.7269877	test: 45.5599185	best: 45.5597168 (147)	total: 52.2s	remaining: 2m
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 45.54300345
# bestIteration = 160
#
# Shrink model to first 161 iterations.
# Warning: Overfitting detector is active, thus evaluation metric iscalculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 0:	learn: 36.6152465	test: 33.9221094	best: 33.9221094 (0)	total: 443ms	remaining: 3m 40s
# 50:	learn: 35.6539505	test: 32.8664661	best: 32.8664661 (50)	total: 18.4s	remaining: 2m 41s
# 100:	learn: 35.4313658	test: 32.6865116	best: 32.6864966 (99)	total: 36.2s	remaining: 2m 22s
# 150:	learn: 35.2936361	test: 32.5881407	best: 32.5881407 (150)	total: 53.8s	remaining: 2m 4s
# 200:	learn: 35.1402468	test: 32.5117200	best: 32.5117200 (200)	total: 1m 11s	remaining: 1m 46s
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 32.49291973
# bestIteration = 209
#
# Shrink model to first 210 iterations.

# %% [markdown]
# At the arbitrary fold size of 8, we still get over sixty-two thousand users, and expect a good number of users to be paying customers.  We reserve 3 of these folds for validation and predicting the log of the sums.  We will also use the previous fold for validation, mostly to save space and time to be honest, though the first and last rounds must be treated separately.

# %% [markdown]
# At a L2 coefficient of 100, trees tend to stop around 100 iterations.  At a coefficient of 1, they stop $O(10)$ iterations, with the RMSE still increasing only 1 unit by the end.  At 1000, the training runs for more iterations, but the gains are just as modest.  There is still the question of whether it is better to let the ensemble components overfit, but we might run into the problem we usually do with random forests.  At this rate, though, the system will do not much better than a small collection of independent decision trees.  We'll go ahead and try anyways.

# %%
del chunk, eval_chunk

# %%
with open('../models/cb_stage1.pkl', 'wb') as f:
    pickle.dump(models, f)

# %% [markdown]
# Effectively doing a weighted average here.  I wonder if tree regressors have something like predict proba to asses how confident it is in each prediction.

# %%
from sklearn.linear_model import LinearRegression

# %%
len(id_holder)
# Out:
# 187473

# %%
val_df = createChunk(id_holder, len(id_holder), False)[0]

# %% [markdown]
# oh my god it's only 93MB.  All this effort to avoid loading the entire dataframe and good fraction of it is just 93MB.

# %%
val_x = val_df.drop('transactionrevenue', axis=1)
val_y = val_df[['fullvisitorid', 'transactionrevenue']]
del val_df

# %%
predicts = [model.predict(val_x) for model in models]

# %%
for i in range(len(models)):
    val_x[f'predicted_{i}'] = predicts[i]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
col_mask = [column=='fullvisitorid' or 'predicted_' in column for column in val_x.columns.values]
x = val_x.loc[:,col_mask].groupby('fullvisitorid').sum()

# %%
x.describe()
# Out:
#          predicted_0    predicted_1    predicted_2    predicted_3  \
# count  187473.000000  187473.000000  187473.000000  187473.000000
# mean        2.024744       2.015175       1.999806       1.968603
# std        12.670578      18.926023      13.953792      17.662588
# min        -0.731466     -17.012426      -1.291338      -6.361899
# 25%        -0.037000      -0.386212      -0.073637      -0.204398
# 50%         0.157122      -0.255843       0.041073      -0.021647
# 75%         0.613433      -0.022711       0.378796       0.398186
# max      1456.764486    2082.520218    1130.844994    2751.167519
#
#          predicted_4
# count  187473.000000
# mean        1.834993
# std        12.120747
# min        -3.322797
# 25%        -0.240298
# 50%        -0.131213
# 75%         0.161302
# max       908.566214

# %% [markdown]
# Just realized some of these will be negative.  We need to transform them with a function that runs from zero to infinity and accepts negative infinity to infinity, or else use a different model.  We try the former here.  Why not, headed down a bad way at this point.

# %%
y = val_y.groupby('fullvisitorid').sum()

# %%
y.describe()
# Out:
#        transactionrevenue
# count       187473.000000
# mean             2.081995
# std             53.622774
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              0.000000
# max           8951.970000

# %%
cbagg = cb.CatBoostRegressor()

# %%
cbagg.fit(x, y)
cbagg.score(x, y)
# Out:
# 0:	learn: 53.5166450	total: 43.9ms	remaining: 43.8s
# 1:	learn: 53.3762209	total: 68.7ms	remaining: 34.3s
# 2:	learn: 53.2484818	total: 92.4ms	remaining: 30.7s
# 3:	learn: 53.1234203	total: 119ms	remaining: 29.7s
# 4:	learn: 53.0053379	total: 162ms	remaining: 32.3s
# 5:	learn: 52.8932759	total: 189ms	remaining: 31.3s
# 6:	learn: 52.7880458	total: 216ms	remaining: 30.6s
# 7:	learn: 52.6881363	total: 240ms	remaining: 29.7s
# 8:	learn: 52.5938717	total: 286ms	remaining: 31.5s
# 9:	learn: 52.5048306	total: 316ms	remaining: 31.2s
# 10:	learn: 52.4232247	total: 351ms	remaining: 31.5s
# 11:	learn: 52.3447308	total: 382ms	remaining: 31.4s
# 12:	learn: 52.2722240	total: 406ms	remaining: 30.8s
# 13:	learn: 52.2010987	total: 436ms	remaining: 30.7s
# 14:	learn: 52.1341082	total: 461ms	remaining: 30.3s
# 15:	learn: 52.0715408	total: 487ms	remaining: 30s
# 16:	learn: 52.0132958	total: 543ms	remaining: 31.4s
# 17:	learn: 51.9573958	total: 577ms	remaining: 31.5s
# 18:	learn: 51.9040579	total: 608ms	remaining: 31.4s
# 19:	learn: 51.8532553	total: 633ms	remaining: 31s
# 20:	learn: 51.8052630	total: 661ms	remaining: 30.8s
# 21:	learn: 51.7598325	total: 693ms	remaining: 30.8s
# 22:	learn: 51.7171154	total: 737ms	remaining: 31.3s
# 23:	learn: 51.6767401	total: 765ms	remaining: 31.1s
# 24:	learn: 51.6387700	total: 790ms	remaining: 30.8s
# 25:	learn: 51.6030708	total: 815ms	remaining: 30.5s
# 26:	learn: 51.5698028	total: 841ms	remaining: 30.3s
# 27:	learn: 51.5374709	total: 864ms	remaining: 30s
# 28:	learn: 51.5067131	total: 891ms	remaining: 29.8s
# 29:	learn: 51.4782439	total: 935ms	remaining: 30.2s
# 30:	learn: 51.4505501	total: 978ms	remaining: 30.6s
# 31:	learn: 51.4247743	total: 1.01s	remaining: 30.5s
# 32:	learn: 51.4007844	total: 1.03s	remaining: 30.3s
# 33:	learn: 51.3786204	total: 1.06s	remaining: 30.1s
# 34:	learn: 51.3569914	total: 1.09s	remaining: 30s
# 35:	learn: 51.3358660	total: 1.12s	remaining: 30s
# 36:	learn: 51.3162626	total: 1.15s	remaining: 29.9s
# 37:	learn: 51.2989276	total: 1.2s	remaining: 30.3s
# 38:	learn: 51.2813701	total: 1.23s	remaining: 30.4s
# 39:	learn: 51.2652333	total: 1.27s	remaining: 30.4s
# 40:	learn: 51.2493814	total: 1.3s	remaining: 30.3s
# 41:	learn: 51.2345188	total: 1.33s	remaining: 30.2s
# 42:	learn: 51.2212329	total: 1.35s	remaining: 30.1s
# 43:	learn: 51.2083247	total: 1.4s	remaining: 30.3s
# 44:	learn: 51.1962685	total: 1.42s	remaining: 30.2s
# 45:	learn: 51.1845518	total: 1.45s	remaining: 30.1s
# 46:	learn: 51.1733094	total: 1.48s	remaining: 30s
# 47:	learn: 51.1624482	total: 1.5s	remaining: 29.8s
# 48:	learn: 51.1515598	total: 1.53s	remaining: 29.7s
# 49:	learn: 51.1428741	total: 1.56s	remaining: 29.7s
# 50:	learn: 51.1351842	total: 1.61s	remaining: 29.9s
# 51:	learn: 51.1260762	total: 1.66s	remaining: 30.4s
# 52:	learn: 51.1172470	total: 1.69s	remaining: 30.2s
# 53:	learn: 51.1090356	total: 1.72s	remaining: 30.1s
# 54:	learn: 51.1012926	total: 1.74s	remaining: 30s
# 55:	learn: 51.0939913	total: 1.77s	remaining: 29.8s
# 56:	learn: 51.0860878	total: 1.81s	remaining: 29.9s
# 57:	learn: 51.0788547	total: 1.84s	remaining: 29.9s
# 58:	learn: 51.0717142	total: 1.87s	remaining: 29.8s
# 59:	learn: 51.0658361	total: 1.89s	remaining: 29.7s
# 60:	learn: 51.0604893	total: 1.93s	remaining: 29.7s
# 61:	learn: 51.0540842	total: 2.01s	remaining: 30.4s
# 62:	learn: 51.0482107	total: 2.07s	remaining: 30.8s
# 63:	learn: 51.0423570	total: 2.14s	remaining: 31.3s
# 64:	learn: 51.0373539	total: 2.2s	remaining: 31.7s
# 65:	learn: 51.0338915	total: 2.26s	remaining: 32s
# 66:	learn: 51.0284522	total: 2.33s	remaining: 32.5s
# 67:	learn: 51.0234801	total: 2.4s	remaining: 32.9s
# 68:	learn: 51.0188084	total: 2.45s	remaining: 33.1s
# 69:	learn: 51.0149628	total: 2.5s	remaining: 33.2s
# 70:	learn: 51.0119207	total: 2.57s	remaining: 33.6s
# 71:	learn: 51.0074683	total: 2.64s	remaining: 34s
# 72:	learn: 51.0036053	total: 2.71s	remaining: 34.4s
# 73:	learn: 50.9994326	total: 2.77s	remaining: 34.6s
# 74:	learn: 50.9957457	total: 2.83s	remaining: 34.9s
# 75:	learn: 50.9922507	total: 2.9s	remaining: 35.2s
# 76:	learn: 50.9894102	total: 2.96s	remaining: 35.5s
# 77:	learn: 50.9857400	total: 3.01s	remaining: 35.6s
# 78:	learn: 50.9825023	total: 3.04s	remaining: 35.4s
# 79:	learn: 50.9778673	total: 3.06s	remaining: 35.2s
# 80:	learn: 50.9745643	total: 3.09s	remaining: 35.1s
# 81:	learn: 50.9714698	total: 3.12s	remaining: 34.9s
# 82:	learn: 50.9685458	total: 3.15s	remaining: 34.8s
# 83:	learn: 50.9659053	total: 3.19s	remaining: 34.8s
# 84:	learn: 50.9628575	total: 3.24s	remaining: 34.8s
# 85:	learn: 50.9602409	total: 3.26s	remaining: 34.7s
# 86:	learn: 50.9571335	total: 3.29s	remaining: 34.6s
# 87:	learn: 50.9550890	total: 3.32s	remaining: 34.4s
# 88:	learn: 50.9524451	total: 3.34s	remaining: 34.2s
# 89:	learn: 50.9506802	total: 3.37s	remaining: 34.1s
# 90:	learn: 50.9480906	total: 3.41s	remaining: 34.1s
# 91:	learn: 50.9460651	total: 3.45s	remaining: 34s
# 92:	learn: 50.9439358	total: 3.48s	remaining: 33.9s
# 93:	learn: 50.9417743	total: 3.53s	remaining: 34s
# 94:	learn: 50.9398343	total: 3.58s	remaining: 34.1s
# 95:	learn: 50.9384266	total: 3.67s	remaining: 34.5s
# 96:	learn: 50.9364925	total: 3.75s	remaining: 34.9s
# 97:	learn: 50.9343974	total: 3.77s	remaining: 34.7s
# 98:	learn: 50.9324441	total: 3.8s	remaining: 34.6s
# 99:	learn: 50.9291856	total: 3.82s	remaining: 34.4s
# 100:	learn: 50.9280938	total: 3.85s	remaining: 34.3s
# 101:	learn: 50.9262260	total: 3.88s	remaining: 34.2s
# 102:	learn: 50.9253197	total: 3.93s	remaining: 34.2s
# 103:	learn: 50.9235528	total: 3.95s	remaining: 34.1s
# 104:	learn: 50.9205202	total: 4.07s	remaining: 34.7s
# 105:	learn: 50.9188749	total: 4.2s	remaining: 35.4s
# 106:	learn: 50.9173394	total: 4.32s	remaining: 36s
# 107:	learn: 50.9157126	total: 4.4s	remaining: 36.4s
# 108:	learn: 50.9140793	total: 4.45s	remaining: 36.4s
# 109:	learn: 50.9126485	total: 4.53s	remaining: 36.6s
# 110:	learn: 50.9111989	total: 4.6s	remaining: 36.8s
# 111:	learn: 50.9097941	total: 4.67s	remaining: 37.1s
# 112:	learn: 50.9083674	total: 4.73s	remaining: 37.2s
# 113:	learn: 50.9070469	total: 4.78s	remaining: 37.1s
# 114:	learn: 50.9052985	total: 4.82s	remaining: 37.1s
# 115:	learn: 50.9026189	total: 4.84s	remaining: 36.9s
# 116:	learn: 50.9006916	total: 4.87s	remaining: 36.7s
# 117:	learn: 50.8999967	total: 4.9s	remaining: 36.6s
# 118:	learn: 50.8987944	total: 4.93s	remaining: 36.5s
# 119:	learn: 50.8975408	total: 4.97s	remaining: 36.4s
# 120:	learn: 50.8963227	total: 5.05s	remaining: 36.7s
# 121:	learn: 50.8957201	total: 5.22s	remaining: 37.6s
# 122:	learn: 50.8952214	total: 5.29s	remaining: 37.7s
# 123:	learn: 50.8941373	total: 5.34s	remaining: 37.7s
# 124:	learn: 50.8931388	total: 5.37s	remaining: 37.6s
# 125:	learn: 50.8926937	total: 5.4s	remaining: 37.5s
# 126:	learn: 50.8921267	total: 5.43s	remaining: 37.4s
# 127:	learn: 50.8910681	total: 5.47s	remaining: 37.3s
# 128:	learn: 50.8900368	total: 5.5s	remaining: 37.1s
# 129:	learn: 50.8879524	total: 5.53s	remaining: 37s
# 130:	learn: 50.8875811	total: 5.56s	remaining: 36.9s
# 131:	learn: 50.8866579	total: 5.61s	remaining: 36.9s
# 132:	learn: 50.8855278	total: 5.65s	remaining: 36.9s
# 133:	learn: 50.8851918	total: 5.7s	remaining: 36.8s
# 134:	learn: 50.8842245	total: 5.73s	remaining: 36.7s
# 135:	learn: 50.8833000	total: 5.76s	remaining: 36.6s
# 136:	learn: 50.8823976	total: 5.79s	remaining: 36.5s
# 137:	learn: 50.8814228	total: 5.82s	remaining: 36.3s
# 138:	learn: 50.8805438	total: 5.85s	remaining: 36.2s
# 139:	learn: 50.8798808	total: 5.88s	remaining: 36.1s
# 140:	learn: 50.8788274	total: 5.92s	remaining: 36.1s
# 141:	learn: 50.8778099	total: 5.95s	remaining: 35.9s
# 142:	learn: 50.8769733	total: 5.97s	remaining: 35.8s
# 143:	learn: 50.8767172	total: 6s	remaining: 35.7s
# 144:	learn: 50.8764740	total: 6.03s	remaining: 35.5s
# 145:	learn: 50.8752318	total: 6.05s	remaining: 35.4s
# 146:	learn: 50.8743461	total: 6.08s	remaining: 35.3s
# 147:	learn: 50.8731568	total: 6.13s	remaining: 35.3s
# 148:	learn: 50.8728347	total: 6.19s	remaining: 35.4s
# 149:	learn: 50.8724748	total: 6.24s	remaining: 35.4s
# 150:	learn: 50.8708852	total: 6.29s	remaining: 35.4s
# 151:	learn: 50.8701235	total: 6.35s	remaining: 35.4s
# 152:	learn: 50.8698327	total: 6.39s	remaining: 35.4s
# 153:	learn: 50.8690278	total: 6.45s	remaining: 35.4s
# 154:	learn: 50.8687521	total: 6.5s	remaining: 35.5s
# 155:	learn: 50.8681392	total: 6.57s	remaining: 35.5s
# 156:	learn: 50.8671607	total: 6.61s	remaining: 35.5s
# 157:	learn: 50.8655268	total: 6.67s	remaining: 35.5s
# 158:	learn: 50.8650784	total: 6.72s	remaining: 35.5s
# 159:	learn: 50.8648513	total: 6.77s	remaining: 35.6s
# 160:	learn: 50.8633589	total: 6.82s	remaining: 35.5s
# 161:	learn: 50.8626486	total: 6.87s	remaining: 35.5s
# 162:	learn: 50.8615895	total: 6.92s	remaining: 35.5s
# 163:	learn: 50.8614325	total: 6.98s	remaining: 35.6s
# 164:	learn: 50.8607427	total: 7.04s	remaining: 35.6s
# 165:	learn: 50.8601069	total: 7.11s	remaining: 35.7s
# 166:	learn: 50.8594434	total: 7.13s	remaining: 35.6s
# 167:	learn: 50.8587930	total: 7.17s	remaining: 35.5s
# 168:	learn: 50.8580807	total: 7.24s	remaining: 35.6s
# 169:	learn: 50.8578593	total: 7.29s	remaining: 35.6s
# 170:	learn: 50.8569681	total: 7.34s	remaining: 35.6s
# 171:	learn: 50.8563770	total: 7.39s	remaining: 35.6s
# 172:	learn: 50.8557029	total: 7.42s	remaining: 35.5s
# 173:	learn: 50.8550962	total: 7.45s	remaining: 35.4s
# 174:	learn: 50.8544869	total: 7.5s	remaining: 35.3s
# 175:	learn: 50.8531021	total: 7.53s	remaining: 35.2s
# 176:	learn: 50.8520618	total: 7.57s	remaining: 35.2s
# 177:	learn: 50.8518063	total: 7.6s	remaining: 35.1s
# 178:	learn: 50.8509028	total: 7.63s	remaining: 35s
# 179:	learn: 50.8495423	total: 7.66s	remaining: 34.9s
# 180:	learn: 50.8489606	total: 7.71s	remaining: 34.9s
# 181:	learn: 50.8471731	total: 7.77s	remaining: 34.9s
# 182:	learn: 50.8470006	total: 7.81s	remaining: 34.9s
# 183:	learn: 50.8461116	total: 7.84s	remaining: 34.8s
# 184:	learn: 50.8455504	total: 7.87s	remaining: 34.7s
# 185:	learn: 50.8450023	total: 7.96s	remaining: 34.8s
# 186:	learn: 50.8447756	total: 8.01s	remaining: 34.8s
# 187:	learn: 50.8442354	total: 8.06s	remaining: 34.8s
# 188:	learn: 50.8432234	total: 8.14s	remaining: 34.9s
# 189:	learn: 50.8424677	total: 8.2s	remaining: 35s
# 190:	learn: 50.8419443	total: 8.23s	remaining: 34.9s
# 191:	learn: 50.8417708	total: 8.28s	remaining: 34.8s
# 192:	learn: 50.8401304	total: 8.31s	remaining: 34.7s
# 193:	learn: 50.8396422	total: 8.34s	remaining: 34.6s
# 194:	learn: 50.8394361	total: 8.38s	remaining: 34.6s
# 195:	learn: 50.8389343	total: 8.41s	remaining: 34.5s
# 196:	learn: 50.8387731	total: 8.43s	remaining: 34.4s
# 197:	learn: 50.8386180	total: 8.46s	remaining: 34.3s
# 198:	learn: 50.8382435	total: 8.49s	remaining: 34.2s
# 199:	learn: 50.8366670	total: 8.51s	remaining: 34.1s
# 200:	learn: 50.8356921	total: 8.54s	remaining: 34s
# 201:	learn: 50.8352155	total: 8.57s	remaining: 33.9s
# 202:	learn: 50.8351349	total: 8.6s	remaining: 33.8s
# 203:	learn: 50.8346683	total: 8.64s	remaining: 33.7s
# 204:	learn: 50.8338619	total: 8.66s	remaining: 33.6s
# 205:	learn: 50.8331287	total: 8.69s	remaining: 33.5s
# 206:	learn: 50.8326830	total: 8.71s	remaining: 33.4s
# 207:	learn: 50.8325033	total: 8.74s	remaining: 33.3s
# 208:	learn: 50.8323311	total: 8.76s	remaining: 33.2s
# 209:	learn: 50.8317901	total: 8.79s	remaining: 33.1s
# 210:	learn: 50.8306678	total: 8.84s	remaining: 33s
# 211:	learn: 50.8302402	total: 8.89s	remaining: 33s
# 212:	learn: 50.8291271	total: 8.94s	remaining: 33s
# 213:	learn: 50.8287074	total: 8.98s	remaining: 33s
# 214:	learn: 50.8285885	total: 9.03s	remaining: 33s
# 215:	learn: 50.8282052	total: 9.09s	remaining: 33s
# 216:	learn: 50.8277147	total: 9.12s	remaining: 32.9s
# 217:	learn: 50.8273157	total: 9.14s	remaining: 32.8s
# 218:	learn: 50.8260766	total: 9.17s	remaining: 32.7s
# 219:	learn: 50.8259225	total: 9.19s	remaining: 32.6s
# 220:	learn: 50.8258615	total: 9.22s	remaining: 32.5s
# 221:	learn: 50.8253756	total: 9.25s	remaining: 32.4s
# 222:	learn: 50.8249914	total: 9.27s	remaining: 32.3s
# 223:	learn: 50.8248460	total: 9.31s	remaining: 32.3s
# 224:	learn: 50.8244696	total: 9.39s	remaining: 32.4s
# 225:	learn: 50.8243311	total: 9.44s	remaining: 32.3s
# 226:	learn: 50.8239622	total: 9.49s	remaining: 32.3s
# 227:	learn: 50.8235996	total: 9.59s	remaining: 32.5s
# 228:	learn: 50.8234686	total: 9.64s	remaining: 32.5s
# 229:	learn: 50.8218525	total: 9.69s	remaining: 32.4s
# 230:	learn: 50.8210718	total: 9.74s	remaining: 32.4s
# 231:	learn: 50.8209463	total: 9.78s	remaining: 32.4s
# 232:	learn: 50.8205964	total: 9.81s	remaining: 32.3s
# 233:	learn: 50.8200697	total: 9.86s	remaining: 32.3s
# 234:	learn: 50.8195852	total: 9.95s	remaining: 32.4s
# 235:	learn: 50.8187067	total: 10s	remaining: 32.4s
# 236:	learn: 50.8179145	total: 10.1s	remaining: 32.4s
# 237:	learn: 50.8178000	total: 10.1s	remaining: 32.4s
# 238:	learn: 50.8177032	total: 10.2s	remaining: 32.4s
# 239:	learn: 50.8173962	total: 10.2s	remaining: 32.4s
# 240:	learn: 50.8169345	total: 10.3s	remaining: 32.4s
# 241:	learn: 50.8168200	total: 10.3s	remaining: 32.4s
# 242:	learn: 50.8162203	total: 10.4s	remaining: 32.3s
# 243:	learn: 50.8154721	total: 10.4s	remaining: 32.2s
# 244:	learn: 50.8153629	total: 10.4s	remaining: 32.1s
# 245:	learn: 50.8152580	total: 10.4s	remaining: 32s
# 246:	learn: 50.8144757	total: 10.5s	remaining: 31.9s
# 247:	learn: 50.8141635	total: 10.5s	remaining: 31.8s
# 248:	learn: 50.8138566	total: 10.5s	remaining: 31.8s
# 249:	learn: 50.8137498	total: 10.6s	remaining: 31.7s
# 250:	learn: 50.8129765	total: 10.6s	remaining: 31.6s
# 251:	learn: 50.8128936	total: 10.6s	remaining: 31.5s
# 252:	learn: 50.8118000	total: 10.6s	remaining: 31.4s
# 253:	learn: 50.8114989	total: 10.7s	remaining: 31.4s
# 254:	learn: 50.8105261	total: 10.7s	remaining: 31.4s
# 255:	learn: 50.8100719	total: 10.8s	remaining: 31.3s
# 256:	learn: 50.8099952	total: 10.8s	remaining: 31.3s
# 257:	learn: 50.8094122	total: 10.8s	remaining: 31.2s
# 258:	learn: 50.8089189	total: 10.9s	remaining: 31.1s
# 259:	learn: 50.8086271	total: 10.9s	remaining: 31.1s
# 260:	learn: 50.8076420	total: 11s	remaining: 31.1s
# 261:	learn: 50.8073549	total: 11s	remaining: 31s
# 262:	learn: 50.8072595	total: 11s	remaining: 30.9s
# 263:	learn: 50.8068786	total: 11.1s	remaining: 30.8s
# 264:	learn: 50.8066207	total: 11.1s	remaining: 30.7s
# 265:	learn: 50.8065309	total: 11.1s	remaining: 30.7s
# 266:	learn: 50.8056084	total: 11.1s	remaining: 30.6s
# 267:	learn: 50.8055707	total: 11.2s	remaining: 30.6s
# 268:	learn: 50.8054848	total: 11.3s	remaining: 30.6s
# 269:	learn: 50.8043881	total: 11.3s	remaining: 30.6s
# 270:	learn: 50.8040580	total: 11.4s	remaining: 30.6s
# 271:	learn: 50.8039665	total: 11.4s	remaining: 30.6s
# 272:	learn: 50.8038779	total: 11.5s	remaining: 30.6s
# 273:	learn: 50.8038438	total: 11.6s	remaining: 30.7s
# 274:	learn: 50.8035960	total: 11.6s	remaining: 30.6s
# 275:	learn: 50.8035109	total: 11.7s	remaining: 30.6s
# 276:	learn: 50.8031974	total: 11.7s	remaining: 30.5s
# 277:	learn: 50.8031147	total: 11.7s	remaining: 30.4s
# 278:	learn: 50.8028542	total: 11.7s	remaining: 30.4s
# 279:	learn: 50.8018657	total: 11.8s	remaining: 30.3s
# 280:	learn: 50.8014983	total: 11.8s	remaining: 30.2s
# 281:	learn: 50.8012424	total: 11.9s	remaining: 30.2s
# 282:	learn: 50.8011781	total: 11.9s	remaining: 30.1s
# 283:	learn: 50.8009265	total: 11.9s	remaining: 30s
# 284:	learn: 50.8006789	total: 11.9s	remaining: 30s
# 285:	learn: 50.8005995	total: 12s	remaining: 29.9s
# 286:	learn: 50.7997872	total: 12s	remaining: 29.8s
# 287:	learn: 50.7987426	total: 12s	remaining: 29.7s
# 288:	learn: 50.7986663	total: 12.1s	remaining: 29.6s
# 289:	learn: 50.7980142	total: 12.1s	remaining: 29.6s
# 290:	learn: 50.7979409	total: 12.1s	remaining: 29.5s
# 291:	learn: 50.7970142	total: 12.2s	remaining: 29.5s
# 292:	learn: 50.7963625	total: 12.2s	remaining: 29.5s
# 293:	learn: 50.7962918	total: 12.3s	remaining: 29.4s
# 294:	learn: 50.7960489	total: 12.3s	remaining: 29.4s
# 295:	learn: 50.7960204	total: 12.3s	remaining: 29.4s
# 296:	learn: 50.7955162	total: 12.4s	remaining: 29.3s
# 297:	learn: 50.7954586	total: 12.4s	remaining: 29.3s
# 298:	learn: 50.7953911	total: 12.5s	remaining: 29.2s
# 299:	learn: 50.7949698	total: 12.5s	remaining: 29.1s
# 300:	learn: 50.7949053	total: 12.5s	remaining: 29.1s
# 301:	learn: 50.7948511	total: 12.6s	remaining: 29s
# 302:	learn: 50.7947894	total: 12.6s	remaining: 28.9s
# 303:	learn: 50.7943580	total: 12.6s	remaining: 28.9s
# 304:	learn: 50.7941192	total: 12.7s	remaining: 28.9s
# 305:	learn: 50.7936855	total: 12.7s	remaining: 28.9s
# 306:	learn: 50.7936262	total: 12.8s	remaining: 28.9s
# 307:	learn: 50.7933936	total: 12.8s	remaining: 28.9s
# 308:	learn: 50.7933445	total: 12.9s	remaining: 28.9s
# 309:	learn: 50.7923718	total: 12.9s	remaining: 28.8s
# 310:	learn: 50.7923017	total: 13s	remaining: 28.7s
# 311:	learn: 50.7920760	total: 13s	remaining: 28.7s
# 312:	learn: 50.7918540	total: 13.1s	remaining: 28.7s
# 313:	learn: 50.7916524	total: 13.1s	remaining: 28.6s
# 314:	learn: 50.7915959	total: 13.1s	remaining: 28.5s
# 315:	learn: 50.7913806	total: 13.1s	remaining: 28.5s
# 316:	learn: 50.7911853	total: 13.2s	remaining: 28.4s
# 317:	learn: 50.7909764	total: 13.2s	remaining: 28.4s
# 318:	learn: 50.7903925	total: 13.3s	remaining: 28.4s
# 319:	learn: 50.7902034	total: 13.3s	remaining: 28.3s
# 320:	learn: 50.7901359	total: 13.4s	remaining: 28.3s
# 321:	learn: 50.7900703	total: 13.4s	remaining: 28.3s
# 322:	learn: 50.7898679	total: 13.5s	remaining: 28.4s
# 323:	learn: 50.7896688	total: 13.6s	remaining: 28.3s
# 324:	learn: 50.7896417	total: 13.6s	remaining: 28.3s
# 325:	learn: 50.7895876	total: 13.7s	remaining: 28.3s
# 326:	learn: 50.7895242	total: 13.7s	remaining: 28.2s
# 327:	learn: 50.7893282	total: 13.7s	remaining: 28.2s
# 328:	learn: 50.7892762	total: 13.8s	remaining: 28.1s
# 329:	learn: 50.7891085	total: 13.8s	remaining: 28s
# 330:	learn: 50.7890856	total: 13.8s	remaining: 28s
# 331:	learn: 50.7885139	total: 13.9s	remaining: 27.9s
# 332:	learn: 50.7884921	total: 13.9s	remaining: 27.9s
# 333:	learn: 50.7883144	total: 13.9s	remaining: 27.8s
# 334:	learn: 50.7881241	total: 14s	remaining: 27.7s
# 335:	learn: 50.7879369	total: 14s	remaining: 27.6s
# 336:	learn: 50.7872287	total: 14s	remaining: 27.6s
# 337:	learn: 50.7872076	total: 14s	remaining: 27.5s
# 338:	learn: 50.7867430	total: 14.1s	remaining: 27.5s
# 339:	learn: 50.7867227	total: 14.1s	remaining: 27.4s
# 340:	learn: 50.7862650	total: 14.2s	remaining: 27.4s
# 341:	learn: 50.7857824	total: 14.2s	remaining: 27.4s
# 342:	learn: 50.7855981	total: 14.3s	remaining: 27.4s
# 343:	learn: 50.7851592	total: 14.3s	remaining: 27.4s
# 344:	learn: 50.7849920	total: 14.4s	remaining: 27.3s
# 345:	learn: 50.7848135	total: 14.5s	remaining: 27.3s
# 346:	learn: 50.7841086	total: 14.5s	remaining: 27.3s
# 347:	learn: 50.7838392	total: 14.6s	remaining: 27.3s
# 348:	learn: 50.7837992	total: 14.6s	remaining: 27.3s
# 349:	learn: 50.7837492	total: 14.7s	remaining: 27.3s
# 350:	learn: 50.7837040	total: 14.7s	remaining: 27.2s
# 351:	learn: 50.7836561	total: 14.7s	remaining: 27.1s
# 352:	learn: 50.7833603	total: 14.8s	remaining: 27.1s
# 353:	learn: 50.7833142	total: 14.8s	remaining: 27s
# 354:	learn: 50.7825345	total: 14.8s	remaining: 26.9s
# 355:	learn: 50.7824566	total: 14.9s	remaining: 26.9s
# 356:	learn: 50.7814901	total: 14.9s	remaining: 26.8s
# 357:	learn: 50.7814458	total: 14.9s	remaining: 26.7s
# 358:	learn: 50.7812743	total: 14.9s	remaining: 26.7s
# 359:	learn: 50.7811057	total: 15s	remaining: 26.6s
# 360:	learn: 50.7809534	total: 15s	remaining: 26.6s
# 361:	learn: 50.7805240	total: 15s	remaining: 26.5s
# 362:	learn: 50.7804807	total: 15.1s	remaining: 26.4s
# 363:	learn: 50.7804390	total: 15.1s	remaining: 26.4s
# 364:	learn: 50.7803988	total: 15.2s	remaining: 26.4s
# 365:	learn: 50.7799197	total: 15.2s	remaining: 26.4s
# 366:	learn: 50.7789353	total: 15.3s	remaining: 26.3s
# 367:	learn: 50.7788967	total: 15.3s	remaining: 26.3s
# 368:	learn: 50.7786850	total: 15.3s	remaining: 26.2s
# 369:	learn: 50.7785064	total: 15.3s	remaining: 26.1s
# 370:	learn: 50.7782993	total: 15.4s	remaining: 26.1s
# 371:	learn: 50.7776916	total: 15.4s	remaining: 26s
# 372:	learn: 50.7776544	total: 15.5s	remaining: 26.1s
# 373:	learn: 50.7774946	total: 15.6s	remaining: 26s
# 374:	learn: 50.7774586	total: 15.6s	remaining: 26s
# 375:	learn: 50.7773012	total: 15.6s	remaining: 25.9s
# 376:	learn: 50.7765709	total: 15.7s	remaining: 25.9s
# 377:	learn: 50.7765172	total: 15.7s	remaining: 25.8s
# 378:	learn: 50.7764650	total: 15.8s	remaining: 25.8s
# 379:	learn: 50.7763237	total: 15.8s	remaining: 25.8s
# 380:	learn: 50.7753931	total: 15.9s	remaining: 25.8s
# 381:	learn: 50.7752403	total: 15.9s	remaining: 25.7s
# 382:	learn: 50.7752056	total: 16s	remaining: 25.7s
# 383:	learn: 50.7746106	total: 16s	remaining: 25.7s
# 384:	learn: 50.7745772	total: 16.1s	remaining: 25.6s
# 385:	learn: 50.7741905	total: 16.1s	remaining: 25.6s
# 386:	learn: 50.7741585	total: 16.1s	remaining: 25.5s
# 387:	learn: 50.7741275	total: 16.1s	remaining: 25.5s
# 388:	learn: 50.7733955	total: 16.2s	remaining: 25.4s
# 389:	learn: 50.7731143	total: 16.2s	remaining: 25.3s
# 390:	learn: 50.7729104	total: 16.2s	remaining: 25.3s
# 391:	learn: 50.7728741	total: 16.2s	remaining: 25.2s
# 392:	learn: 50.7728445	total: 16.3s	remaining: 25.1s
# 393:	learn: 50.7723051	total: 16.3s	remaining: 25.1s
# 394:	learn: 50.7722567	total: 16.3s	remaining: 25s
# 395:	learn: 50.7721211	total: 16.4s	remaining: 25s
# 396:	learn: 50.7716067	total: 16.4s	remaining: 24.9s
# 397:	learn: 50.7712364	total: 16.4s	remaining: 24.8s
# 398:	learn: 50.7704127	total: 16.5s	remaining: 24.8s
# 399:	learn: 50.7702671	total: 16.5s	remaining: 24.7s
# 400:	learn: 50.7702204	total: 16.5s	remaining: 24.7s
# 401:	learn: 50.7698635	total: 16.5s	remaining: 24.6s
# 402:	learn: 50.7696852	total: 16.6s	remaining: 24.6s
# 403:	learn: 50.7695462	total: 16.7s	remaining: 24.6s
# 404:	learn: 50.7695010	total: 16.7s	remaining: 24.5s
# 405:	learn: 50.7694717	total: 16.8s	remaining: 24.5s
# 406:	learn: 50.7694278	total: 16.8s	remaining: 24.5s
# 407:	learn: 50.7692546	total: 16.8s	remaining: 24.4s
# 408:	learn: 50.7684356	total: 16.9s	remaining: 24.4s
# 409:	learn: 50.7683002	total: 16.9s	remaining: 24.3s
# 410:	learn: 50.7682718	total: 16.9s	remaining: 24.3s
# 411:	learn: 50.7682444	total: 17s	remaining: 24.3s
# 412:	learn: 50.7681109	total: 17.1s	remaining: 24.2s
# 413:	learn: 50.7673031	total: 17.1s	remaining: 24.2s
# 414:	learn: 50.7667720	total: 17.2s	remaining: 24.2s
# 415:	learn: 50.7660903	total: 17.2s	remaining: 24.1s
# 416:	learn: 50.7659605	total: 17.2s	remaining: 24.1s
# 417:	learn: 50.7657584	total: 17.3s	remaining: 24.1s
# 418:	learn: 50.7657416	total: 17.3s	remaining: 24s
# 419:	learn: 50.7656156	total: 17.3s	remaining: 24s
# 420:	learn: 50.7653058	total: 17.4s	remaining: 23.9s
# 421:	learn: 50.7651820	total: 17.4s	remaining: 23.9s
# 422:	learn: 50.7644333	total: 17.5s	remaining: 23.8s
# 423:	learn: 50.7643114	total: 17.5s	remaining: 23.8s
# 424:	learn: 50.7642952	total: 17.6s	remaining: 23.8s
# 425:	learn: 50.7638398	total: 17.6s	remaining: 23.7s
# 426:	learn: 50.7629700	total: 17.7s	remaining: 23.7s
# 427:	learn: 50.7623089	total: 17.7s	remaining: 23.7s
# 428:	learn: 50.7622818	total: 17.8s	remaining: 23.7s
# 429:	learn: 50.7618068	total: 17.8s	remaining: 23.7s
# 430:	learn: 50.7613646	total: 17.9s	remaining: 23.6s
# 431:	learn: 50.7607906	total: 17.9s	remaining: 23.6s
# 432:	learn: 50.7603533	total: 18s	remaining: 23.5s
# 433:	learn: 50.7600776	total: 18s	remaining: 23.4s
# 434:	learn: 50.7600375	total: 18s	remaining: 23.4s
# 435:	learn: 50.7594983	total: 18s	remaining: 23.3s
# 436:	learn: 50.7593817	total: 18.1s	remaining: 23.3s
# 437:	learn: 50.7592671	total: 18.1s	remaining: 23.2s
# 438:	learn: 50.7592407	total: 18.1s	remaining: 23.2s
# 439:	learn: 50.7592152	total: 18.1s	remaining: 23.1s
# 440:	learn: 50.7591841	total: 18.2s	remaining: 23s
# 441:	learn: 50.7590709	total: 18.2s	remaining: 23s
# 442:	learn: 50.7589698	total: 18.2s	remaining: 22.9s
# 443:	learn: 50.7584655	total: 18.3s	remaining: 22.9s
# 444:	learn: 50.7583556	total: 18.3s	remaining: 22.8s
# 445:	learn: 50.7582958	total: 18.3s	remaining: 22.8s
# 446:	learn: 50.7579802	total: 18.4s	remaining: 22.7s
# 447:	learn: 50.7578720	total: 18.4s	remaining: 22.7s
# 448:	learn: 50.7573422	total: 18.4s	remaining: 22.6s
# 449:	learn: 50.7573175	total: 18.5s	remaining: 22.6s
# 450:	learn: 50.7572938	total: 18.5s	remaining: 22.6s
# 451:	learn: 50.7570141	total: 18.6s	remaining: 22.6s
# 452:	learn: 50.7569911	total: 18.6s	remaining: 22.5s
# 453:	learn: 50.7568840	total: 18.7s	remaining: 22.4s
# 454:	learn: 50.7568616	total: 18.7s	remaining: 22.4s
# 455:	learn: 50.7568401	total: 18.7s	remaining: 22.3s
# 456:	learn: 50.7568193	total: 18.7s	remaining: 22.3s
# 457:	learn: 50.7567134	total: 18.8s	remaining: 22.2s
# 458:	learn: 50.7566931	total: 18.8s	remaining: 22.2s
# 459:	learn: 50.7565888	total: 18.8s	remaining: 22.1s
# 460:	learn: 50.7565594	total: 18.9s	remaining: 22.1s
# 461:	learn: 50.7565397	total: 19s	remaining: 22.1s
# 462:	learn: 50.7565207	total: 19s	remaining: 22s
# 463:	learn: 50.7560604	total: 19.1s	remaining: 22s
# 464:	learn: 50.7560219	total: 19.1s	remaining: 22s
# 465:	learn: 50.7559189	total: 19.1s	remaining: 21.9s
# 466:	learn: 50.7558909	total: 19.1s	remaining: 21.9s
# 467:	learn: 50.7558615	total: 19.2s	remaining: 21.8s
# 468:	learn: 50.7558240	total: 19.2s	remaining: 21.7s
# 469:	learn: 50.7555585	total: 19.2s	remaining: 21.7s
# 470:	learn: 50.7555221	total: 19.3s	remaining: 21.6s
# 471:	learn: 50.7550834	total: 19.3s	remaining: 21.6s
# 472:	learn: 50.7549820	total: 19.4s	remaining: 21.6s
# 473:	learn: 50.7549674	total: 19.4s	remaining: 21.5s
# 474:	learn: 50.7549410	total: 19.4s	remaining: 21.5s
# 475:	learn: 50.7549270	total: 19.5s	remaining: 21.4s
# 476:	learn: 50.7546527	total: 19.5s	remaining: 21.4s
# 477:	learn: 50.7545636	total: 19.6s	remaining: 21.4s
# 478:	learn: 50.7540616	total: 19.6s	remaining: 21.3s
# 479:	learn: 50.7534135	total: 19.7s	remaining: 21.3s
# 480:	learn: 50.7534001	total: 19.7s	remaining: 21.3s
# 481:	learn: 50.7533814	total: 19.8s	remaining: 21.2s
# 482:	learn: 50.7533546	total: 19.8s	remaining: 21.2s
# 483:	learn: 50.7533290	total: 19.9s	remaining: 21.2s
# 484:	learn: 50.7532146	total: 19.9s	remaining: 21.2s
# 485:	learn: 50.7530861	total: 20s	remaining: 21.1s
# 486:	learn: 50.7529898	total: 20s	remaining: 21.1s
# 487:	learn: 50.7528953	total: 20s	remaining: 21s
# 488:	learn: 50.7526679	total: 20.1s	remaining: 21s
# 489:	learn: 50.7526327	total: 20.1s	remaining: 20.9s
# 490:	learn: 50.7525378	total: 20.1s	remaining: 20.9s
# 491:	learn: 50.7521274	total: 20.2s	remaining: 20.8s
# 492:	learn: 50.7521095	total: 20.2s	remaining: 20.8s
# 493:	learn: 50.7520173	total: 20.2s	remaining: 20.7s
# 494:	learn: 50.7519267	total: 20.3s	remaining: 20.7s
# 495:	learn: 50.7519091	total: 20.3s	remaining: 20.6s
# 496:	learn: 50.7513746	total: 20.3s	remaining: 20.6s
# 497:	learn: 50.7513575	total: 20.3s	remaining: 20.5s
# 498:	learn: 50.7513235	total: 20.4s	remaining: 20.4s
# 499:	learn: 50.7508753	total: 20.4s	remaining: 20.4s
# 500:	learn: 50.7504348	total: 20.4s	remaining: 20.4s
# 501:	learn: 50.7504184	total: 20.5s	remaining: 20.3s
# 502:	learn: 50.7503292	total: 20.5s	remaining: 20.2s
# 503:	learn: 50.7501770	total: 20.5s	remaining: 20.2s
# 504:	learn: 50.7499527	total: 20.6s	remaining: 20.2s
# 505:	learn: 50.7498065	total: 20.6s	remaining: 20.1s
# 506:	learn: 50.7497905	total: 20.7s	remaining: 20.1s
# 507:	learn: 50.7497575	total: 20.7s	remaining: 20.1s
# 508:	learn: 50.7496697	total: 20.8s	remaining: 20s
# 509:	learn: 50.7492952	total: 20.8s	remaining: 20s
# 510:	learn: 50.7491290	total: 20.8s	remaining: 19.9s
# 511:	learn: 50.7488660	total: 20.8s	remaining: 19.9s
# 512:	learn: 50.7488534	total: 20.9s	remaining: 19.8s
# 513:	learn: 50.7488413	total: 20.9s	remaining: 19.8s
# 514:	learn: 50.7487555	total: 21s	remaining: 19.7s
# 515:	learn: 50.7481829	total: 21s	remaining: 19.7s
# 516:	learn: 50.7480985	total: 21s	remaining: 19.6s
# 517:	learn: 50.7475500	total: 21s	remaining: 19.6s
# 518:	learn: 50.7475336	total: 21.1s	remaining: 19.5s
# 519:	learn: 50.7471481	total: 21.1s	remaining: 19.5s
# 520:	learn: 50.7470726	total: 21.2s	remaining: 19.5s
# 521:	learn: 50.7470609	total: 21.2s	remaining: 19.4s
# 522:	learn: 50.7470368	total: 21.3s	remaining: 19.4s
# 523:	learn: 50.7470142	total: 21.4s	remaining: 19.4s
# 524:	learn: 50.7469319	total: 21.4s	remaining: 19.4s
# 525:	learn: 50.7467307	total: 21.5s	remaining: 19.4s
# 526:	learn: 50.7466990	total: 21.5s	remaining: 19.3s
# 527:	learn: 50.7466679	total: 21.6s	remaining: 19.3s
# 528:	learn: 50.7466376	total: 21.6s	remaining: 19.3s
# 529:	learn: 50.7466145	total: 21.7s	remaining: 19.2s
# 530:	learn: 50.7459842	total: 21.7s	remaining: 19.2s
# 531:	learn: 50.7456775	total: 21.7s	remaining: 19.1s
# 532:	learn: 50.7455974	total: 21.8s	remaining: 19.1s
# 533:	learn: 50.7454891	total: 21.8s	remaining: 19s
# 534:	learn: 50.7454114	total: 21.8s	remaining: 19s
# 535:	learn: 50.7453956	total: 21.9s	remaining: 19s
# 536:	learn: 50.7451872	total: 22s	remaining: 18.9s
# 537:	learn: 50.7451720	total: 22s	remaining: 18.9s
# 538:	learn: 50.7451573	total: 22.1s	remaining: 18.9s
# 539:	learn: 50.7451431	total: 22.1s	remaining: 18.9s
# 540:	learn: 50.7449687	total: 22.2s	remaining: 18.8s
# 541:	learn: 50.7447222	total: 22.2s	remaining: 18.8s
# 542:	learn: 50.7447086	total: 22.2s	remaining: 18.7s
# 543:	learn: 50.7446791	total: 22.3s	remaining: 18.7s
# 544:	learn: 50.7446016	total: 22.3s	remaining: 18.6s
# 545:	learn: 50.7445883	total: 22.3s	remaining: 18.6s
# 546:	learn: 50.7445771	total: 22.3s	remaining: 18.5s
# 547:	learn: 50.7445088	total: 22.4s	remaining: 18.5s
# 548:	learn: 50.7444335	total: 22.4s	remaining: 18.4s
# 549:	learn: 50.7444139	total: 22.4s	remaining: 18.4s
# 550:	learn: 50.7444009	total: 22.5s	remaining: 18.3s
# 551:	learn: 50.7443266	total: 22.5s	remaining: 18.3s
# 552:	learn: 50.7443157	total: 22.5s	remaining: 18.2s
# 553:	learn: 50.7439304	total: 22.6s	remaining: 18.2s
# 554:	learn: 50.7438574	total: 22.6s	remaining: 18.1s
# 555:	learn: 50.7437040	total: 22.6s	remaining: 18.1s
# 556:	learn: 50.7436910	total: 22.6s	remaining: 18s
# 557:	learn: 50.7431625	total: 22.7s	remaining: 18s
# 558:	learn: 50.7431441	total: 22.8s	remaining: 18s
# 559:	learn: 50.7431152	total: 22.9s	remaining: 18s
# 560:	learn: 50.7431047	total: 23s	remaining: 18s
# 561:	learn: 50.7429303	total: 23s	remaining: 17.9s
# 562:	learn: 50.7428594	total: 23.1s	remaining: 17.9s
# 563:	learn: 50.7428311	total: 23.1s	remaining: 17.9s
# 564:	learn: 50.7427683	total: 23.2s	remaining: 17.9s
# 565:	learn: 50.7426809	total: 23.3s	remaining: 17.8s
# 566:	learn: 50.7424986	total: 23.4s	remaining: 17.8s
# 567:	learn: 50.7424860	total: 23.4s	remaining: 17.8s
# 568:	learn: 50.7422564	total: 23.5s	remaining: 17.8s
# 569:	learn: 50.7421884	total: 23.6s	remaining: 17.8s
# 570:	learn: 50.7417634	total: 23.6s	remaining: 17.7s
# 571:	learn: 50.7417357	total: 23.7s	remaining: 17.7s
# 572:	learn: 50.7415083	total: 23.7s	remaining: 17.7s
# 573:	learn: 50.7414873	total: 23.8s	remaining: 17.6s
# 574:	learn: 50.7414772	total: 23.8s	remaining: 17.6s
# 575:	learn: 50.7414674	total: 23.8s	remaining: 17.5s
# 576:	learn: 50.7414549	total: 23.9s	remaining: 17.5s
# 577:	learn: 50.7412114	total: 23.9s	remaining: 17.4s
# 578:	learn: 50.7406274	total: 23.9s	remaining: 17.4s
# 579:	learn: 50.7405615	total: 23.9s	remaining: 17.3s
# 580:	learn: 50.7405344	total: 24s	remaining: 17.3s
# 581:	learn: 50.7405222	total: 24s	remaining: 17.2s
# 582:	learn: 50.7404957	total: 24s	remaining: 17.2s
# 583:	learn: 50.7404698	total: 24s	remaining: 17.1s
# 584:	learn: 50.7402703	total: 24.1s	remaining: 17.1s
# 585:	learn: 50.7402585	total: 24.1s	remaining: 17.1s
# 586:	learn: 50.7401933	total: 24.2s	remaining: 17s
# 587:	learn: 50.7401818	total: 24.3s	remaining: 17s
# 588:	learn: 50.7400066	total: 24.3s	remaining: 17s
# 589:	learn: 50.7399955	total: 24.4s	remaining: 17s
# 590:	learn: 50.7399861	total: 24.5s	remaining: 17s
# 591:	learn: 50.7399281	total: 24.6s	remaining: 16.9s
# 592:	learn: 50.7399173	total: 24.7s	remaining: 16.9s
# 593:	learn: 50.7398920	total: 24.8s	remaining: 16.9s
# 594:	learn: 50.7395447	total: 24.8s	remaining: 16.9s
# 595:	learn: 50.7395198	total: 24.9s	remaining: 16.8s
# 596:	learn: 50.7390676	total: 24.9s	remaining: 16.8s
# 597:	learn: 50.7390485	total: 25s	remaining: 16.8s
# 598:	learn: 50.7390396	total: 25s	remaining: 16.8s
# 599:	learn: 50.7389758	total: 25.1s	remaining: 16.7s
# 600:	learn: 50.7389131	total: 25.1s	remaining: 16.7s
# 601:	learn: 50.7388109	total: 25.2s	remaining: 16.6s
# 602:	learn: 50.7387563	total: 25.2s	remaining: 16.6s
# 603:	learn: 50.7386962	total: 25.3s	remaining: 16.6s
# 604:	learn: 50.7386372	total: 25.4s	remaining: 16.6s
# 605:	learn: 50.7386284	total: 25.4s	remaining: 16.5s
# 606:	learn: 50.7385703	total: 25.5s	remaining: 16.5s
# 607:	learn: 50.7385455	total: 25.6s	remaining: 16.5s
# 608:	learn: 50.7385342	total: 25.6s	remaining: 16.5s
# 609:	learn: 50.7384769	total: 25.7s	remaining: 16.4s
# 610:	learn: 50.7380216	total: 25.7s	remaining: 16.4s
# 611:	learn: 50.7380106	total: 25.8s	remaining: 16.4s
# 612:	learn: 50.7379864	total: 25.9s	remaining: 16.3s
# 613:	learn: 50.7379758	total: 25.9s	remaining: 16.3s
# 614:	learn: 50.7379576	total: 26s	remaining: 16.3s
# 615:	learn: 50.7379474	total: 26.1s	remaining: 16.2s
# 616:	learn: 50.7376441	total: 26.1s	remaining: 16.2s
# 617:	learn: 50.7366800	total: 26.2s	remaining: 16.2s
# 618:	learn: 50.7366625	total: 26.2s	remaining: 16.1s
# 619:	learn: 50.7366456	total: 26.3s	remaining: 16.1s
# 620:	learn: 50.7366292	total: 26.3s	remaining: 16.1s
# 621:	learn: 50.7366056	total: 26.3s	remaining: 16s
# 622:	learn: 50.7365957	total: 26.4s	remaining: 16s
# 623:	learn: 50.7365385	total: 26.4s	remaining: 15.9s
# 624:	learn: 50.7365289	total: 26.4s	remaining: 15.9s
# 625:	learn: 50.7365058	total: 26.5s	remaining: 15.8s
# 626:	learn: 50.7364494	total: 26.5s	remaining: 15.8s
# 627:	learn: 50.7361911	total: 26.5s	remaining: 15.7s
# 628:	learn: 50.7361815	total: 26.5s	remaining: 15.7s
# 629:	learn: 50.7361315	total: 26.6s	remaining: 15.6s
# 630:	learn: 50.7360223	total: 26.6s	remaining: 15.6s
# 631:	learn: 50.7360130	total: 26.6s	remaining: 15.5s
# 632:	learn: 50.7359492	total: 26.7s	remaining: 15.5s
# 633:	learn: 50.7359265	total: 26.7s	remaining: 15.4s
# 634:	learn: 50.7354649	total: 26.7s	remaining: 15.4s
# 635:	learn: 50.7354559	total: 26.8s	remaining: 15.3s
# 636:	learn: 50.7354008	total: 26.8s	remaining: 15.3s
# 637:	learn: 50.7353785	total: 26.8s	remaining: 15.2s
# 638:	learn: 50.7353243	total: 26.9s	remaining: 15.2s
# 639:	learn: 50.7353153	total: 26.9s	remaining: 15.2s
# 640:	learn: 50.7348945	total: 27s	remaining: 15.1s
# 641:	learn: 50.7348858	total: 27s	remaining: 15.1s
# 642:	learn: 50.7346574	total: 27.1s	remaining: 15s
# 643:	learn: 50.7346490	total: 27.1s	remaining: 15s
# 644:	learn: 50.7346409	total: 27.1s	remaining: 14.9s
# 645:	learn: 50.7346253	total: 27.2s	remaining: 14.9s
# 646:	learn: 50.7346035	total: 27.2s	remaining: 14.8s
# 647:	learn: 50.7345954	total: 27.2s	remaining: 14.8s
# 648:	learn: 50.7345741	total: 27.3s	remaining: 14.8s
# 649:	learn: 50.7342310	total: 27.3s	remaining: 14.7s
# 650:	learn: 50.7342232	total: 27.3s	remaining: 14.7s
# 651:	learn: 50.7342156	total: 27.4s	remaining: 14.6s
# 652:	learn: 50.7339929	total: 27.4s	remaining: 14.6s
# 653:	learn: 50.7339856	total: 27.4s	remaining: 14.5s
# 654:	learn: 50.7336860	total: 27.5s	remaining: 14.5s
# 655:	learn: 50.7335736	total: 27.5s	remaining: 14.4s
# 656:	learn: 50.7335529	total: 27.5s	remaining: 14.4s
# 657:	learn: 50.7335458	total: 27.5s	remaining: 14.3s
# 658:	learn: 50.7334803	total: 27.6s	remaining: 14.3s
# 659:	learn: 50.7332162	total: 27.6s	remaining: 14.2s
# 660:	learn: 50.7332083	total: 27.6s	remaining: 14.2s
# 661:	learn: 50.7332007	total: 27.6s	remaining: 14.1s
# 662:	learn: 50.7331805	total: 27.7s	remaining: 14.1s
# 663:	learn: 50.7325840	total: 27.7s	remaining: 14s
# 664:	learn: 50.7325770	total: 27.7s	remaining: 14s
# 665:	learn: 50.7324180	total: 27.8s	remaining: 13.9s
# 666:	learn: 50.7323655	total: 27.8s	remaining: 13.9s
# 667:	learn: 50.7319903	total: 27.8s	remaining: 13.8s
# 668:	learn: 50.7319440	total: 27.9s	remaining: 13.8s
# 669:	learn: 50.7319370	total: 27.9s	remaining: 13.7s
# 670:	learn: 50.7319227	total: 27.9s	remaining: 13.7s
# 671:	learn: 50.7311633	total: 27.9s	remaining: 13.6s
# 672:	learn: 50.7311559	total: 28s	remaining: 13.6s
# 673:	learn: 50.7309739	total: 28s	remaining: 13.5s
# 674:	learn: 50.7309227	total: 28.1s	remaining: 13.5s
# 675:	learn: 50.7308724	total: 28.1s	remaining: 13.5s
# 676:	learn: 50.7308653	total: 28.2s	remaining: 13.5s
# 677:	learn: 50.7308581	total: 28.3s	remaining: 13.4s
# 678:	learn: 50.7304902	total: 28.3s	remaining: 13.4s
# 679:	learn: 50.7302387	total: 28.4s	remaining: 13.3s
# 680:	learn: 50.7302108	total: 28.4s	remaining: 13.3s
# 681:	learn: 50.7302040	total: 28.5s	remaining: 13.3s
# 682:	learn: 50.7301906	total: 28.5s	remaining: 13.2s
# 683:	learn: 50.7301841	total: 28.6s	remaining: 13.2s
# 684:	learn: 50.7297535	total: 28.6s	remaining: 13.2s
# 685:	learn: 50.7297339	total: 28.7s	remaining: 13.1s
# 686:	learn: 50.7297270	total: 28.8s	remaining: 13.1s
# 687:	learn: 50.7295371	total: 28.8s	remaining: 13.1s
# 688:	learn: 50.7291952	total: 28.9s	remaining: 13s
# 689:	learn: 50.7291885	total: 28.9s	remaining: 13s
# 690:	learn: 50.7289109	total: 29s	remaining: 13s
# 691:	learn: 50.7288981	total: 29.1s	remaining: 12.9s
# 692:	learn: 50.7288916	total: 29.1s	remaining: 12.9s
# 693:	learn: 50.7288852	total: 29.2s	remaining: 12.9s
# 694:	learn: 50.7288790	total: 29.2s	remaining: 12.8s
# 695:	learn: 50.7288730	total: 29.4s	remaining: 12.8s
# 696:	learn: 50.7283639	total: 29.4s	remaining: 12.8s
# 697:	learn: 50.7283449	total: 29.5s	remaining: 12.8s
# 698:	learn: 50.7283391	total: 29.5s	remaining: 12.7s
# 699:	learn: 50.7283329	total: 29.6s	remaining: 12.7s
# 700:	learn: 50.7282836	total: 29.7s	remaining: 12.7s
# 701:	learn: 50.7282650	total: 29.8s	remaining: 12.6s
# 702:	learn: 50.7280999	total: 29.8s	remaining: 12.6s
# 703:	learn: 50.7280817	total: 29.9s	remaining: 12.6s
# 704:	learn: 50.7280759	total: 29.9s	remaining: 12.5s
# 705:	learn: 50.7280703	total: 30s	remaining: 12.5s
# 706:	learn: 50.7280222	total: 30s	remaining: 12.4s
# 707:	learn: 50.7280167	total: 30.1s	remaining: 12.4s
# 708:	learn: 50.7280114	total: 30.1s	remaining: 12.4s
# 709:	learn: 50.7279385	total: 30.2s	remaining: 12.3s
# 710:	learn: 50.7279337	total: 30.3s	remaining: 12.3s
# 711:	learn: 50.7279276	total: 30.3s	remaining: 12.3s
# 712:	learn: 50.7279229	total: 30.4s	remaining: 12.2s
# 713:	learn: 50.7276250	total: 30.4s	remaining: 12.2s
# 714:	learn: 50.7276203	total: 30.5s	remaining: 12.1s
# 715:	learn: 50.7275790	total: 30.5s	remaining: 12.1s
# 716:	learn: 50.7275611	total: 30.6s	remaining: 12.1s
# 717:	learn: 50.7275566	total: 30.6s	remaining: 12s
# 718:	learn: 50.7275522	total: 30.7s	remaining: 12s
# 719:	learn: 50.7272339	total: 30.8s	remaining: 12s
# 720:	learn: 50.7272297	total: 30.8s	remaining: 11.9s
# 721:	learn: 50.7272287	total: 30.9s	remaining: 11.9s
# 722:	learn: 50.7272112	total: 30.9s	remaining: 11.8s
# 723:	learn: 50.7268080	total: 31s	remaining: 11.8s
# 724:	learn: 50.7263499	total: 31s	remaining: 11.8s
# 725:	learn: 50.7263327	total: 31.1s	remaining: 11.7s
# 726:	learn: 50.7262761	total: 31.2s	remaining: 11.7s
# 727:	learn: 50.7262359	total: 31.2s	remaining: 11.7s
# 728:	learn: 50.7262191	total: 31.3s	remaining: 11.6s
# 729:	learn: 50.7262068	total: 31.3s	remaining: 11.6s
# 730:	learn: 50.7261948	total: 31.3s	remaining: 11.5s
# 731:	learn: 50.7261904	total: 31.4s	remaining: 11.5s
# 732:	learn: 50.7261740	total: 31.4s	remaining: 11.4s
# 733:	learn: 50.7256695	total: 31.4s	remaining: 11.4s
# 734:	learn: 50.7252909	total: 31.4s	remaining: 11.3s
# 735:	learn: 50.7251653	total: 31.5s	remaining: 11.3s
# 736:	learn: 50.7251611	total: 31.5s	remaining: 11.3s
# 737:	learn: 50.7251449	total: 31.6s	remaining: 11.2s
# 738:	learn: 50.7251391	total: 31.6s	remaining: 11.2s
# 739:	learn: 50.7249498	total: 31.7s	remaining: 11.1s
# 740:	learn: 50.7249457	total: 31.8s	remaining: 11.1s
# 741:	learn: 50.7249299	total: 31.8s	remaining: 11.1s
# 742:	learn: 50.7249144	total: 31.9s	remaining: 11s
# 743:	learn: 50.7249030	total: 31.9s	remaining: 11s
# 744:	learn: 50.7248973	total: 32s	remaining: 10.9s
# 745:	learn: 50.7245874	total: 32s	remaining: 10.9s
# 746:	learn: 50.7245758	total: 32s	remaining: 10.8s
# 747:	learn: 50.7245718	total: 32s	remaining: 10.8s
# 748:	learn: 50.7245680	total: 32.1s	remaining: 10.7s
# 749:	learn: 50.7245528	total: 32.1s	remaining: 10.7s
# 750:	learn: 50.7245474	total: 32.2s	remaining: 10.7s
# 751:	learn: 50.7245433	total: 32.2s	remaining: 10.6s
# 752:	learn: 50.7245321	total: 32.2s	remaining: 10.6s
# 753:	learn: 50.7244370	total: 32.3s	remaining: 10.5s
# 754:	learn: 50.7244332	total: 32.3s	remaining: 10.5s
# 755:	learn: 50.7244266	total: 32.3s	remaining: 10.4s
# 756:	learn: 50.7241312	total: 32.4s	remaining: 10.4s
# 757:	learn: 50.7241260	total: 32.4s	remaining: 10.3s
# 758:	learn: 50.7241152	total: 32.4s	remaining: 10.3s
# 759:	learn: 50.7241116	total: 32.4s	remaining: 10.2s
# 760:	learn: 50.7240714	total: 32.5s	remaining: 10.2s
# 761:	learn: 50.7240256	total: 32.5s	remaining: 10.2s
# 762:	learn: 50.7240107	total: 32.6s	remaining: 10.1s
# 763:	learn: 50.7240070	total: 32.7s	remaining: 10.1s
# 764:	learn: 50.7238689	total: 32.7s	remaining: 10.1s
# 765:	learn: 50.7238243	total: 32.8s	remaining: 10s
# 766:	learn: 50.7237793	total: 32.8s	remaining: 9.98s
# 767:	learn: 50.7235864	total: 32.9s	remaining: 9.93s
# 768:	learn: 50.7234514	total: 32.9s	remaining: 9.88s
# 769:	learn: 50.7234080	total: 32.9s	remaining: 9.84s
# 770:	learn: 50.7233416	total: 33s	remaining: 9.79s
# 771:	learn: 50.7232990	total: 33s	remaining: 9.76s
# 772:	learn: 50.7232952	total: 33.1s	remaining: 9.71s
# 773:	learn: 50.7232805	total: 33.1s	remaining: 9.67s
# 774:	learn: 50.7232756	total: 33.1s	remaining: 9.62s
# 775:	learn: 50.7232612	total: 33.2s	remaining: 9.59s
# 776:	learn: 50.7232193	total: 33.3s	remaining: 9.55s
# 777:	learn: 50.7231197	total: 33.3s	remaining: 9.51s
# 778:	learn: 50.7229331	total: 33.4s	remaining: 9.47s
# 779:	learn: 50.7229154	total: 33.4s	remaining: 9.43s
# 780:	learn: 50.7229016	total: 33.5s	remaining: 9.39s
# 781:	learn: 50.7227940	total: 33.5s	remaining: 9.35s
# 782:	learn: 50.7227533	total: 33.6s	remaining: 9.31s
# 783:	learn: 50.7227133	total: 33.6s	remaining: 9.26s
# 784:	learn: 50.7227029	total: 33.7s	remaining: 9.22s
# 785:	learn: 50.7226636	total: 33.7s	remaining: 9.17s
# 786:	learn: 50.7226502	total: 33.7s	remaining: 9.12s
# 787:	learn: 50.7226116	total: 33.7s	remaining: 9.07s
# 788:	learn: 50.7226015	total: 33.8s	remaining: 9.03s
# 789:	learn: 50.7225974	total: 33.8s	remaining: 8.98s
# 790:	learn: 50.7224502	total: 33.8s	remaining: 8.93s
# 791:	learn: 50.7224462	total: 33.8s	remaining: 8.89s
# 792:	learn: 50.7224424	total: 33.9s	remaining: 8.84s
# 793:	learn: 50.7224292	total: 33.9s	remaining: 8.8s
# 794:	learn: 50.7224255	total: 33.9s	remaining: 8.75s
# 795:	learn: 50.7224219	total: 34s	remaining: 8.7s
# 796:	learn: 50.7224185	total: 34s	remaining: 8.65s
# 797:	learn: 50.7223846	total: 34s	remaining: 8.61s
# 798:	learn: 50.7223466	total: 34s	remaining: 8.56s
# 799:	learn: 50.7220819	total: 34.1s	remaining: 8.52s
# 800:	learn: 50.7219865	total: 34.1s	remaining: 8.48s
# 801:	learn: 50.7214408	total: 34.2s	remaining: 8.44s
# 802:	learn: 50.7214034	total: 34.2s	remaining: 8.39s
# 803:	learn: 50.7213998	total: 34.3s	remaining: 8.36s
# 804:	learn: 50.7213900	total: 34.3s	remaining: 8.32s
# 805:	learn: 50.7213574	total: 34.4s	remaining: 8.28s
# 806:	learn: 50.7213521	total: 34.5s	remaining: 8.24s
# 807:	learn: 50.7212457	total: 34.5s	remaining: 8.2s
# 808:	learn: 50.7212411	total: 34.6s	remaining: 8.16s
# 809:	learn: 50.7212283	total: 34.6s	remaining: 8.12s
# 810:	learn: 50.7212250	total: 34.7s	remaining: 8.08s
# 811:	learn: 50.7212217	total: 34.7s	remaining: 8.04s
# 812:	learn: 50.7212092	total: 34.8s	remaining: 8s
# 813:	learn: 50.7211970	total: 34.8s	remaining: 7.96s
# 814:	learn: 50.7211064	total: 34.9s	remaining: 7.91s
# 815:	learn: 50.7211020	total: 34.9s	remaining: 7.88s
# 816:	learn: 50.7210902	total: 35s	remaining: 7.85s
# 817:	learn: 50.7210400	total: 35.1s	remaining: 7.81s
# 818:	learn: 50.7210278	total: 35.2s	remaining: 7.77s
# 819:	learn: 50.7210235	total: 35.2s	remaining: 7.73s
# 820:	learn: 50.7209550	total: 35.3s	remaining: 7.69s
# 821:	learn: 50.7209434	total: 35.3s	remaining: 7.64s
# 822:	learn: 50.7208389	total: 35.3s	remaining: 7.59s
# 823:	learn: 50.7208348	total: 35.3s	remaining: 7.55s
# 824:	learn: 50.7208316	total: 35.4s	remaining: 7.5s
# 825:	learn: 50.7208203	total: 35.4s	remaining: 7.46s
# 826:	learn: 50.7208109	total: 35.4s	remaining: 7.41s
# 827:	learn: 50.7204397	total: 35.5s	remaining: 7.37s
# 828:	learn: 50.7204286	total: 35.5s	remaining: 7.32s
# 829:	learn: 50.7204228	total: 35.5s	remaining: 7.27s
# 830:	learn: 50.7204196	total: 35.5s	remaining: 7.22s
# 831:	learn: 50.7204087	total: 35.6s	remaining: 7.18s
# 832:	learn: 50.7204056	total: 35.6s	remaining: 7.13s
# 833:	learn: 50.7203950	total: 35.6s	remaining: 7.09s
# 834:	learn: 50.7203920	total: 35.6s	remaining: 7.04s
# 835:	learn: 50.7203891	total: 35.7s	remaining: 7s
# 836:	learn: 50.7203787	total: 35.7s	remaining: 6.95s
# 837:	learn: 50.7203194	total: 35.7s	remaining: 6.91s
# 838:	learn: 50.7203166	total: 35.8s	remaining: 6.87s
# 839:	learn: 50.7202846	total: 35.8s	remaining: 6.82s
# 840:	learn: 50.7201828	total: 35.9s	remaining: 6.78s
# 841:	learn: 50.7201727	total: 35.9s	remaining: 6.74s
# 842:	learn: 50.7201364	total: 36s	remaining: 6.7s
# 843:	learn: 50.7201265	total: 36s	remaining: 6.65s
# 844:	learn: 50.7199615	total: 36s	remaining: 6.61s
# 845:	learn: 50.7199525	total: 36.1s	remaining: 6.57s
# 846:	learn: 50.7199169	total: 36.1s	remaining: 6.52s
# 847:	learn: 50.7199082	total: 36.1s	remaining: 6.48s
# 848:	learn: 50.7196324	total: 36.2s	remaining: 6.43s
# 849:	learn: 50.7194052	total: 36.2s	remaining: 6.38s
# 850:	learn: 50.7194013	total: 36.2s	remaining: 6.34s
# 851:	learn: 50.7193984	total: 36.2s	remaining: 6.29s
# 852:	learn: 50.7192777	total: 36.3s	remaining: 6.25s
# 853:	learn: 50.7192748	total: 36.3s	remaining: 6.21s
# 854:	learn: 50.7185586	total: 36.3s	remaining: 6.16s
# 855:	learn: 50.7185558	total: 36.4s	remaining: 6.12s
# 856:	learn: 50.7185476	total: 36.4s	remaining: 6.07s
# 857:	learn: 50.7185378	total: 36.4s	remaining: 6.02s
# 858:	learn: 50.7185024	total: 36.4s	remaining: 5.98s
# 859:	learn: 50.7184408	total: 36.5s	remaining: 5.93s
# 860:	learn: 50.7184064	total: 36.5s	remaining: 5.89s
# 861:	learn: 50.7184035	total: 36.5s	remaining: 5.84s
# 862:	learn: 50.7183955	total: 36.5s	remaining: 5.8s
# 863:	learn: 50.7183616	total: 36.6s	remaining: 5.76s
# 864:	learn: 50.7183322	total: 36.6s	remaining: 5.71s
# 865:	learn: 50.7182962	total: 36.6s	remaining: 5.67s
# 866:	learn: 50.7182933	total: 36.7s	remaining: 5.63s
# 867:	learn: 50.7182838	total: 36.7s	remaining: 5.59s
# 868:	learn: 50.7182810	total: 36.8s	remaining: 5.55s
# 869:	learn: 50.7181023	total: 36.9s	remaining: 5.51s
# 870:	learn: 50.7180996	total: 36.9s	remaining: 5.47s
# 871:	learn: 50.7180667	total: 37s	remaining: 5.43s
# 872:	learn: 50.7180640	total: 37s	remaining: 5.39s
# 873:	learn: 50.7180614	total: 37.1s	remaining: 5.36s
# 874:	learn: 50.7178789	total: 37.2s	remaining: 5.32s
# 875:	learn: 50.7178752	total: 37.3s	remaining: 5.28s
# 876:	learn: 50.7178427	total: 37.3s	remaining: 5.24s
# 877:	learn: 50.7178333	total: 37.4s	remaining: 5.2s
# 878:	learn: 50.7178242	total: 37.4s	remaining: 5.16s
# 879:	learn: 50.7178206	total: 37.5s	remaining: 5.12s
# 880:	learn: 50.7178198	total: 37.6s	remaining: 5.08s
# 881:	learn: 50.7178146	total: 37.6s	remaining: 5.04s
# 882:	learn: 50.7178120	total: 37.7s	remaining: 4.99s
# 883:	learn: 50.7178044	total: 37.7s	remaining: 4.95s
# 884:	learn: 50.7177724	total: 37.8s	remaining: 4.91s
# 885:	learn: 50.7177409	total: 37.9s	remaining: 4.87s
# 886:	learn: 50.7177101	total: 37.9s	remaining: 4.83s
# 887:	learn: 50.7177010	total: 37.9s	remaining: 4.78s
# 888:	learn: 50.7176922	total: 38s	remaining: 4.74s
# 889:	learn: 50.7176579	total: 38s	remaining: 4.7s
# 890:	learn: 50.7176552	total: 38s	remaining: 4.65s
# 891:	learn: 50.7175182	total: 38.1s	remaining: 4.61s
# 892:	learn: 50.7175132	total: 38.1s	remaining: 4.56s
# 893:	learn: 50.7175105	total: 38.1s	remaining: 4.52s
# 894:	learn: 50.7175080	total: 38.2s	remaining: 4.47s
# 895:	learn: 50.7175046	total: 38.2s	remaining: 4.44s
# 896:	learn: 50.7173557	total: 38.3s	remaining: 4.39s
# 897:	learn: 50.7173524	total: 38.3s	remaining: 4.35s
# 898:	learn: 50.7173361	total: 38.4s	remaining: 4.31s
# 899:	learn: 50.7173288	total: 38.4s	remaining: 4.27s
# 900:	learn: 50.7173139	total: 38.5s	remaining: 4.22s
# 901:	learn: 50.7173114	total: 38.5s	remaining: 4.18s
# 902:	learn: 50.7173028	total: 38.6s	remaining: 4.14s
# 903:	learn: 50.7172943	total: 38.6s	remaining: 4.1s
# 904:	learn: 50.7172919	total: 38.7s	remaining: 4.06s
# 905:	learn: 50.7172837	total: 38.7s	remaining: 4.02s
# 906:	learn: 50.7172529	total: 38.8s	remaining: 3.97s
# 907:	learn: 50.7172448	total: 38.8s	remaining: 3.93s
# 908:	learn: 50.7172424	total: 38.8s	remaining: 3.89s
# 909:	learn: 50.7172345	total: 38.9s	remaining: 3.84s
# 910:	learn: 50.7172074	total: 38.9s	remaining: 3.8s
# 911:	learn: 50.7169841	total: 38.9s	remaining: 3.75s
# 912:	learn: 50.7169763	total: 38.9s	remaining: 3.71s
# 913:	learn: 50.7169739	total: 39s	remaining: 3.67s
# 914:	learn: 50.7169439	total: 39s	remaining: 3.62s
# 915:	learn: 50.7169365	total: 39.1s	remaining: 3.58s
# 916:	learn: 50.7169342	total: 39.2s	remaining: 3.54s
# 917:	learn: 50.7169149	total: 39.2s	remaining: 3.5s
# 918:	learn: 50.7167124	total: 39.2s	remaining: 3.46s
# 919:	learn: 50.7167102	total: 39.2s	remaining: 3.41s
# 920:	learn: 50.7167080	total: 39.3s	remaining: 3.37s
# 921:	learn: 50.7167059	total: 39.3s	remaining: 3.32s
# 922:	learn: 50.7166984	total: 39.3s	remaining: 3.28s
# 923:	learn: 50.7166687	total: 39.4s	remaining: 3.24s
# 924:	learn: 50.7166655	total: 39.5s	remaining: 3.2s
# 925:	learn: 50.7164853	total: 39.5s	remaining: 3.15s
# 926:	learn: 50.7164832	total: 39.5s	remaining: 3.11s
# 927:	learn: 50.7164609	total: 39.6s	remaining: 3.07s
# 928:	learn: 50.7164589	total: 39.6s	remaining: 3.03s
# 929:	learn: 50.7164517	total: 39.7s	remaining: 2.99s
# 930:	learn: 50.7164497	total: 39.8s	remaining: 2.95s
# 931:	learn: 50.7164424	total: 39.8s	remaining: 2.9s
# 932:	learn: 50.7164354	total: 39.9s	remaining: 2.86s
# 933:	learn: 50.7164063	total: 39.9s	remaining: 2.82s
# 934:	learn: 50.7163995	total: 40s	remaining: 2.78s
# 935:	learn: 50.7162492	total: 40.1s	remaining: 2.74s
# 936:	learn: 50.7162472	total: 40.1s	remaining: 2.7s
# 937:	learn: 50.7162401	total: 40.2s	remaining: 2.65s
# 938:	learn: 50.7162371	total: 40.2s	remaining: 2.61s
# 939:	learn: 50.7162300	total: 40.2s	remaining: 2.57s
# 940:	learn: 50.7162232	total: 40.3s	remaining: 2.52s
# 941:	learn: 50.7162213	total: 40.3s	remaining: 2.48s
# 942:	learn: 50.7162195	total: 40.3s	remaining: 2.44s
# 943:	learn: 50.7162130	total: 40.4s	remaining: 2.39s
# 944:	learn: 50.7162112	total: 40.4s	remaining: 2.35s
# 945:	learn: 50.7162095	total: 40.4s	remaining: 2.31s
# 946:	learn: 50.7162079	total: 40.5s	remaining: 2.26s
# 947:	learn: 50.7162063	total: 40.5s	remaining: 2.22s
# 948:	learn: 50.7161772	total: 40.6s	remaining: 2.18s
# 949:	learn: 50.7161756	total: 40.6s	remaining: 2.14s
# 950:	learn: 50.7161741	total: 40.7s	remaining: 2.1s
# 951:	learn: 50.7161673	total: 40.7s	remaining: 2.05s
# 952:	learn: 50.7161387	total: 40.8s	remaining: 2.01s
# 953:	learn: 50.7161372	total: 40.8s	remaining: 1.97s
# 954:	learn: 50.7161090	total: 40.9s	remaining: 1.93s
# 955:	learn: 50.7159419	total: 40.9s	remaining: 1.88s
# 956:	learn: 50.7159390	total: 41s	remaining: 1.84s
# 957:	learn: 50.7159375	total: 41s	remaining: 1.8s
# 958:	learn: 50.7159309	total: 41.1s	remaining: 1.76s
# 959:	learn: 50.7159294	total: 41.1s	remaining: 1.71s
# 960:	learn: 50.7159265	total: 41.1s	remaining: 1.67s
# 961:	learn: 50.7159201	total: 41.2s	remaining: 1.63s
# 962:	learn: 50.7159137	total: 41.2s	remaining: 1.58s
# 963:	learn: 50.7158859	total: 41.2s	remaining: 1.54s
# 964:	learn: 50.7158832	total: 41.3s	remaining: 1.5s
# 965:	learn: 50.7158767	total: 41.4s	remaining: 1.46s
# 966:	learn: 50.7158741	total: 41.4s	remaining: 1.41s
# 967:	learn: 50.7158726	total: 41.4s	remaining: 1.37s
# 968:	learn: 50.7158711	total: 41.5s	remaining: 1.33s
# 969:	learn: 50.7157240	total: 41.5s	remaining: 1.28s
# 970:	learn: 50.7157214	total: 41.5s	remaining: 1.24s
# 971:	learn: 50.7157200	total: 41.6s	remaining: 1.2s
# 972:	learn: 50.7155469	total: 41.6s	remaining: 1.15s
# 973:	learn: 50.7155194	total: 41.7s	remaining: 1.11s
# 974:	learn: 50.7155180	total: 41.7s	remaining: 1.07s
# 975:	learn: 50.7155117	total: 41.7s	remaining: 1.03s
# 976:	learn: 50.7154847	total: 41.8s	remaining: 983ms
# 977:	learn: 50.7154786	total: 41.8s	remaining: 941ms
# 978:	learn: 50.7154724	total: 41.9s	remaining: 898ms
# 979:	learn: 50.7154664	total: 41.9s	remaining: 856ms
# 980:	learn: 50.7152389	total: 42s	remaining: 814ms
# 981:	learn: 50.7150469	total: 42.1s	remaining: 771ms
# 982:	learn: 50.7150410	total: 42.1s	remaining: 729ms
# 983:	learn: 50.7150396	total: 42.2s	remaining: 686ms
# 984:	learn: 50.7150339	total: 42.2s	remaining: 643ms
# 985:	learn: 50.7150325	total: 42.3s	remaining: 600ms
# 986:	learn: 50.7150312	total: 42.3s	remaining: 557ms
# 987:	learn: 50.7149759	total: 42.3s	remaining: 514ms
# 988:	learn: 50.7149746	total: 42.3s	remaining: 471ms
# 989:	learn: 50.7149689	total: 42.4s	remaining: 428ms
# 990:	learn: 50.7149676	total: 42.5s	remaining: 386ms
# 991:	learn: 50.7149620	total: 42.5s	remaining: 343ms
# 992:	learn: 50.7149608	total: 42.6s	remaining: 300ms
# 993:	learn: 50.7149552	total: 42.6s	remaining: 257ms
# 994:	learn: 50.7149497	total: 42.6s	remaining: 214ms
# 995:	learn: 50.7149485	total: 42.6s	remaining: 171ms
# 996:	learn: 50.7149431	total: 42.7s	remaining: 128ms
# 997:	learn: 50.7149419	total: 42.7s	remaining: 85.6ms
# 998:	learn: 50.7149408	total: 42.8s	remaining: 42.8ms
# 999:	learn: 50.7145430	total: 42.8s	remaining: 0us
# 50.714543203500675
